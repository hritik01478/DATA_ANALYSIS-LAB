# %% [markdown]
# <a href="https://colab.research.google.com/github/urmila-24/DATA_ANALYSIS-LAB/blob/main/201951164_Urmila_Rathore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv(r'/content/health.csv')
print(data)
print (data.shape)
# Out:
#      Vaccine                 Country Name      2000 [YR2000]  \
# 0       HIB3                  Afghanistan                 ..
# 1       HIB3  Africa Eastern and Southern   5.10608022226771
# 2       HIB3   Africa Western and Central  0.461609931536671
# 3       HIB3                      Albania                 ..
# 4       HIB3                      Algeria                 ..
# ...      ...                          ...                ...
# 1857    POL3           West Bank and Gaza                 ..
# 1858    POL3                        World   73.5751895869048
# 1859    POL3                  Yemen, Rep.                 74
# 1860    POL3                       Zambia                 85
# 1861    POL3                     Zimbabwe                 78
#
#           2001 [YR2001]     2002 [YR2002]     2003 [YR2003]     2004 [YR2004]  \
# 0                    ..                ..                ..                ..
# ...

# %%
import sys
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

data=pd.read_csv("/content/health.csv")
data
# Out:
#      Vaccine                 Country Name      2000 [YR2000]  \
# 0       HIB3                  Afghanistan                 ..
# 1       HIB3  Africa Eastern and Southern   5.10608022226771
# 2       HIB3   Africa Western and Central  0.461609931536671
# 3       HIB3                      Albania                 ..
# 4       HIB3                      Algeria                 ..
# ...      ...                          ...                ...
# 1857    POL3           West Bank and Gaza                 ..
# 1858    POL3                        World   73.5751895869048
# 1859    POL3                  Yemen, Rep.                 74
# 1860    POL3                       Zambia                 85
# 1861    POL3                     Zimbabwe                 78
#
#           2001 [YR2001]     2002 [YR2002]     2003 [YR2003]     2004 [YR2004]  \
# 0                    ..                ..                ..                ..
# ...

# %%
print(data.columns[9])
# Out:
# 2007 [YR2007]

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1862 entries, 0 to 1861
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Vaccine        1862 non-null   object
#  1   Country Name   1862 non-null   object
#  2   2000 [YR2000]  1862 non-null   object
#  3   2001 [YR2001]  1862 non-null   object
#  4   2002 [YR2002]  1862 non-null   object
#  5   2003 [YR2003]  1862 non-null   object
#  6   2004 [YR2004]  1862 non-null   object
#  7   2005 [YR2005]  1862 non-null   object
#  8   2006 [YR2006]  1862 non-null   object
#  9   2007 [YR2007]  1862 non-null   object
#  10  2008 [YR2008]  1862 non-null   object
#  11  2009 [YR2009]  1862 non-null   object
#  12  2010 [YR2010]  1862 non-null   object
#  13  2011 [YR2011]  1862 non-null   object
#  14  2012 [YR2012]  1862 non-null   object
#  15  2013 [YR2013]  1862 non-null   object
#  16  2014 [YR2014]  1862 non-null   object
# ...

# %%
data=data.replace('..', np.nan)
count = data.isna().sum().sum()
print(count)
# Out:
# 8172

# %%
columns=list(data.columns.values[11:])
data[columns]=data[columns].astype("float64")
data.info()

# %%
data_2015=data[{"Vaccine","Country Name","2015 [YR2015]"}]
data_2015

data_hib3=data_2015.loc[data_2015["Vaccine"]=="HIB3"]
print(data_hib3.loc[data_hib3["Country Name"]=="India"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1862 entries, 0 to 1861
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Vaccine        1862 non-null   object
#  1   Country Name   1862 non-null   object
#  2   2000 [YR2000]  1227 non-null   object
#  3   2001 [YR2001]  1267 non-null   object
#  4   2002 [YR2002]  1309 non-null   object
#  5   2003 [YR2003]  1339 non-null   object
#  6   2004 [YR2004]  1358 non-null   object
#  7   2005 [YR2005]  1385 non-null   object
#  8   2006 [YR2006]  1401 non-null   object
#  9   2007 [YR2007]  1424 non-null   object
#  10  2008 [YR2008]  1446 non-null   object
#  11  2009 [YR2009]  1477 non-null   object
#  12  2010 [YR2010]  1492 non-null   object
#  13  2011 [YR2011]  1510 non-null   object
#  14  2012 [YR2012]  1521 non-null   object
#  15  2013 [YR2013]  1535 non-null   object
#  16  2014 [YR2014]  1547 non-null   object
# ...

# %%
data[data.columns[11:]]=data[data.columns[11:]].astype('float') 
check=data[data['Country Name']=='India']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-b4bb2a1ae5bf> in <module>()
# ----> 1 data[data.columns[11:]]=data[data.columns[11:]].astype('float')
#       2 check=data[data['Country Name']=='India']
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...
