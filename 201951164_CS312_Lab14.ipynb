# %% [markdown]
# <a href="https://colab.research.google.com/github/urmila-24/DATA_ANALYSIS-LAB/blob/main/201951164_CS312_Lab14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats

df=pd.read_csv('IPL_Auction_2022_FullList.csv')
df
# Out:
#      Set No. Set Name               Player       Country State Association  \
# 0          1        M          Trent Boult   New Zealand               NaN
# 1          1        M          Pat Cummins     Australia               NaN
# 2          1        M       Shikhar Dhawan         India              DDCA
# 3          1        M         Shreyas Iyer         India               MCA
# 4          1        M        Kagiso Rabada  South Africa               NaN
# ..       ...      ...                  ...           ...               ...
# 584       62    UAL15       Safyaan Sharif      Scotland               NaN
# 585       62    UAL15        Henry Shipley   New Zealand               NaN
# 586       62    UAL15  Maxwell Swaminathan         India               MCA
# 587       62    UAL15        Johan Van Dyk  South Africa               NaN
# 588       62    UAL15     Dunith Wellalage     Sri Lanka               NaN
#
#      Age   Specialism Batting                 Bowling    IPL  \
# ...

# %%
# Contingency table from ”Specialism” and ”Batting” type of player.
coc=pd.crosstab(df["Batting"], df["Specialism"])

# %%
coc
# Out:
# Specialism  ALL-ROUNDER  BATSMAN  BOWLER  WICKETKEEPER
# Batting
# LHB                  75       36      50            13
# RHB                 152       66     152            45

# %%
box = [1] * 174
box.extend([0] * 415)
random.shuffle(box)

# %%
def chi2(observed, expected):
    pearson_residuals = []
    for row, expect in zip(observed, expected):
        tmp=[]
        for observe in row:
            R=(observe - expect) ** 2 / expect
            tmp.append(R)
        pearson_residuals.append(tmp)
    X=np.sum(pearson_residuals)
    return X

# %%
expected_lhb = 174/4
expected_rhb = 500 - expected_lhb
expected = [expected_lhb, expected_rhb]
chi2observed = chi2(coc.values, expected)
print(f'Observed chi2: {chi2observed:.4f}')
# Out:
# Observed chi2: 1157.6602

# %%
chisq, pvalue, df, expected = stats.chi2_contingency(coc)
print(f'Observed chi2: {chi2observed:.4f}')
print(f'p-value: {pvalue:.4f}')
# Out:
# Observed chi2: 1157.6602
# p-value: 0.0859
